# %%
import pandas as pd
import numpy as np
import ast

# %%
file = '../../data/oriental_store/oriental_store_products.csv'

# %%
df = pd.read_csv(file, index_col=0)

# %%
def clean_specs(specs_string:dict):
    
    if specs_string == '{}' or pd.isna(specs_string):
        return ''


    try:
        specs_dict = ast.literal_eval(specs_string.lower())

        key_specs = ['processor',
                    'memory',
                    'storage',
                    'graphic']

    
        
        cleaned_specs = ' '.join(list(specs_dict.values()))

        return cleaned_specs
        
    except:
        return ''

# %%
def clean_categories(categories_string:set):

    if categories_string == '{}' or pd.isna(categories_string):
        return ''

    try:
        categories_set = ast.literal_eval(categories_string)

        cleaned_categories = str(categories_set).replace('\'', '').lower()[1:-1]

        return cleaned_categories

    except Exception as e:
        print(e)
        return ''

# %%
def preprocess_file(file_path):

    df = pd.read_csv(file, index_col=0)

    valid_df = df[df['in_stock'] == True].copy()

    valid_df['price'] = valid_df['price'].astype(np.float64)
    valid_df['original_price'] = valid_df['original_price'].fillna(valid_df['price'])
    
    valid_df = valid_df.drop(columns=['in_stock','currency'])

    valid_df['product_name'] = valid_df['product_name'].apply(str.lower)

    valid_df['brand'] = valid_df['brand'].apply(str.lower)
    
    valid_df['specs'] = valid_df['specs'].apply(clean_specs)

    valid_df['categories'] = valid_df['categories'].apply(clean_categories)

    valid_df.loc[valid_df['product_description'] == 'Unknown','product_description'] = 'No Description'

    model_text = (valid_df['brand'] + ' ' +
                    valid_df['product_name'] + ' ' +
                    valid_df['specs'])
                   

    valid_df['model_text'] = model_text

    

    return valid_df

# %%
d = preprocess_file(file)

# %%
d.head()
# Out:
#          product_code                                       product_name  \
# 0             D501MER  asus expertcenter d5 mini tower (d501mer) busi...
# 1             B5TQ8AA  hp omnidesk desktop pc (m02-0234) amd ryzen 7 ...
# 2             BE8B1AA  hp omen 35l gaming pc (dt gt16-0344) (pre-buil...
# 3             BC4K6AA  hp omen 16l gaming pc (dt tg03-0154) (pre-buil...
# 4  1M-285BJO-B3100UXX  msi cubi 1m mini pc, portable mini pc desktop,...
#
#   brand           store                                                url  \
# 0  asus  Oriental Store  https://os-jo.com/asus-expertcenter-d5-mini-to...
# 1    hp  Oriental Store  https://os-jo.com/hp-omnidesk-desktop-pc-m02-0...
# 2    hp  Oriental Store  https://os-jo.com/hp-omen-35l-gaming-pc-dt-gt1...
# 3    hp  Oriental Store  https://os-jo.com/hp-omen-16l-gaming-pc-dt-tg0...
# 4   msi  Oriental Store  https://os-jo.com/msi-cubi-1m-mini-pc-portable...
#
#                                            image_url   price  original_price  \
# 0  https://os-jo.com/image/cache/catalog/products...   599.0           599.0
# 1  https://os-jo.com/image/cache/catalog/products...   629.0           629.0
# 2  https://os-jo.com/image/cache/catalog/products...  1169.0          1169.0
# 3  https://os-jo.com/image/cache/catalog/products...   929.0           929.0
# 4  https://os-jo.com/image/cache/catalog/products...   259.0           259.0
#
#   product_description                                         categories  \
# 0      No Description  apple, gaming pc, gaming laptop and gaming acc...
# 1      No Description  apple, gaming pc, gaming laptop and gaming acc...
# 2      No Description  apple, gaming pc, gaming laptop and gaming acc...
# 3      No Description  apple, gaming pc, gaming laptop and gaming acc...
# 4      No Description  apple, gaming pc, gaming laptop and gaming acc...
#
#                                                specs  \
# 0  core i7 14th generation i7-14700 up to 5.4ghz ...
# 1  amd ryzen 7 8700g up to 5.1ghz 16mb 8 16 1x16g...
# 2  amd ryzen 7 8700f amd b650  1 usb type-c® 10gb...
# 3  intel core i5 14400f intel® h770  4x usb 2.0 t...
# 4  core 3 intel core (series 1) 100u up to 4.7ghz...
#
#                                           model_text
# 0  asus asus expertcenter d5 mini tower (d501mer)...
# 1  hp hp omnidesk desktop pc (m02-0234) amd ryzen...
# 2  hp hp omen 35l gaming pc (dt gt16-0344) (pre-b...
# 3  hp hp omen 16l gaming pc (dt tg03-0154) (pre-b...
# 4  msi msi cubi 1m mini pc, portable mini pc desk...

# %%
d['model_text'][0]
# Out:
# 'asus asus expertcenter d5 mini tower (d501mer) business desktop 14th gen intel core i7-14700, 8gb ddr5 memory, intel uhd graphics, 512gb m.2 nvme gen 4 ssd, w/ 180w 80+ bronze power supply apple, gaming pc, gaming laptop and gaming accessories, intel, gaming pc, desktops computer, asus, hp, msi, lenovo, amd, computer systems, dell core i7 14th generation i7-14700 up to 5.4ghz 33mb 20 (8p+12e) 28 threads 8gb (1 x 8gb) ddr5 2 m.2 pcie nvme ssd pcie 4.0 512gb intel intel® uhd graphics 770 shared memory integrated memory no *front i/o ports  1x smart card reader  1x 2 in 1 card reader sd / mmc  2x usb 3.2 gen 2 type-a  2x usb 2.0 type-a  1x 3.5mm combo audio jack  1x headphone  *rear i/o ports  2x usb 3.2 gen 1 type-a  2x usb 2.0 type-a  1x padlock loop  1x kensington lock  1x 7.1 channel audio (microphone  line-out  line-in)  1x vga port  1x hdmi 1.4  1x rj45 gigabit ethernet high definition 7.1 channel audio free dos rj45 gigabit ethernet 10/100/1000  wi-fi 6(802.11ax) (dual band) 2*2 + bluetooth® 5.4 wireless card wired keyboard + mouse 1 year intel® b760 chipset'

# %%
len(d['model_text'][0])
# Out:
# 1078

# %%
df.head()
# Out:
#          product_code                                       product_name  \
# 0             D501MER  ASUS ExpertCenter D5 Mini Tower (D501MER) Busi...
# 1             B5TQ8AA  HP OmniDesk Desktop PC (M02-0234) AMD Ryzen 7 ...
# 2             BE8B1AA  HP OMEN 35L Gaming PC (DT GT16-0344) (Pre-Buil...
# 3             BC4K6AA  HP OMEN 16L Gaming PC (DT TG03-0154) (Pre-Buil...
# 4  1M-285BJO-B3100UXX  MSI Cubi 1M Mini PC, Portable Mini PC Desktop,...
#
#   brand           store                                                url  \
# 0  ASUS  Oriental Store  https://os-jo.com/asus-expertcenter-d5-mini-to...
# 1    HP  Oriental Store  https://os-jo.com/hp-omnidesk-desktop-pc-m02-0...
# 2    HP  Oriental Store  https://os-jo.com/hp-omen-35l-gaming-pc-dt-gt1...
# 3    HP  Oriental Store  https://os-jo.com/hp-omen-16l-gaming-pc-dt-tg0...
# 4   MSI  Oriental Store  https://os-jo.com/msi-cubi-1m-mini-pc-portable...
#
#                                            image_url   price  original_price  \
# 0  https://os-jo.com/image/cache/catalog/products...   599.0             NaN
# 1  https://os-jo.com/image/cache/catalog/products...   629.0             NaN
# 2  https://os-jo.com/image/cache/catalog/products...  1169.0             NaN
# 3  https://os-jo.com/image/cache/catalog/products...   929.0             NaN
# 4  https://os-jo.com/image/cache/catalog/products...   259.0             NaN
#
#   currency  in_stock product_description  \
# 0      JOD      True             Unknown
# 1      JOD      True             Unknown
# 2      JOD      True             Unknown
# 3      JOD      True             Unknown
# 4      JOD      True             Unknown
#
#                                           categories  \
# 0  {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
# 1  {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
# 2  {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
# 3  {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
# 4  {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
#
#                                                specs
# 0  {'Processor Type': 'Core i7', 'Processor Gener...
# 1  {'Processor Type': 'AMD', 'Processor Generatio...
# 2  {'Processor': 'AMD RYZEN 7 8700F', 'Motherboar...
# 3  {'Processor': 'INTEL CORE I5 14400F', 'Motherb...
# 4  {'Processor Type': 'Core 3', 'Processor Genera...

# %%
df['categories'][0]
# Out:
# "{'Apple', 'Lenovo', 'Computer Systems', 'Dell', 'Gaming PC', 'AMD', 'Gaming PC, Gaming Laptop and Gaming Accessories', 'Desktops Computer', 'Intel', 'MSI', 'HP', 'ASUS'}"

# %%
r = ast.literal_eval(df['specs'][0])

# %%
key_specs = {'processor',
                    'memory',
                    'storage',
                    'graphic'}

# %%
q = list(r.items())[0][0]

# %%
q.lower().split()
# Out:
# ['processor', 'type']

# %%
df.describe(include='all')
# Out:
#        product_code product_name brand           store  \
# count          5041         5041  5041            5041
# unique         4281         5034    75               1
# top        OS BUILD      Unknown  ASUS  Oriental Store
# freq            184            3   428            5041
# mean            NaN          NaN   NaN             NaN
# std             NaN          NaN   NaN             NaN
# min             NaN          NaN   NaN             NaN
# 25%             NaN          NaN   NaN             NaN
# 50%             NaN          NaN   NaN             NaN
# 75%             NaN          NaN   NaN             NaN
# max             NaN          NaN   NaN             NaN
#
#                                                       url  \
# count                                                5041
# unique                                               5041
# top     https://os-jo.com/asus-expertcenter-d5-mini-to...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                 image_url         price  \
# count                                                5034   5038.000000
# unique                                               4419           NaN
# top     https://os-jo.com/image/cache/catalog/products...           NaN
# freq                                                   23           NaN
# mean                                                  NaN    359.976372
# std                                                   NaN    772.243669
# min                                                   NaN      0.000000
# 25%                                                   NaN     49.000000
# 50%                                                   NaN    129.000000
# 75%                                                   NaN    379.000000
# max                                                   NaN  31999.000000
#
#         original_price currency in_stock product_description  \
# count      1117.000000     5041     5041                4067
# unique             NaN        2        2                 459
# top                NaN      JOD    False             Unknown
# freq               NaN     5038     3796                3501
# mean        519.400179      NaN      NaN                 NaN
# std         648.346907      NaN      NaN                 NaN
# min          10.000000      NaN      NaN                 NaN
# 25%          95.000000      NaN      NaN                 NaN
# 50%         245.000000      NaN      NaN                 NaN
# 75%         729.000000      NaN      NaN                 NaN
# max        4999.000000      NaN      NaN                 NaN
#
#                                                categories specs
# count                                                5041  5041
# unique                                                 81  3846
# top     {'Gaming PC', 'AMD', 'Gaming PC, Gaming Laptop...    {}
# freq                                                  377   734
# mean                                                  NaN   NaN
# std                                                   NaN   NaN
# min                                                   NaN   NaN
# 25%                                                   NaN   NaN
# 50%                                                   NaN   NaN
# 75%                                                   NaN   NaN
# max                                                   NaN   NaN

# %%
df['price'] = df['price'].astype(object)

# %%
df['original_price'] = df['original_price'].astype(object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5041 entries, 0 to 5040
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_code         5041 non-null   object
#  1   product_name         5041 non-null   object
#  2   brand                5041 non-null   object
#  3   store                5041 non-null   object
#  4   url                  5041 non-null   object
#  5   image_url            5034 non-null   object
#  6   price                5038 non-null   float64
#  7   original_price       1117 non-null   float64
#  8   currency             5041 non-null   object
#  9   in_stock             5041 non-null   bool
#  10  product_description  4067 non-null   object
#  11  categories           5041 non-null   object
#  12  specs                5041 non-null   object
# dtypes: bool(1), float64(2), object(10)
# memory usage: 516.9+ KB

# %%
df.describe()
# Out:
#        product_code product_name brand           store  \
# count          5041         5041  5041            5041
# unique         4281         5034    75               1
# top        OS BUILD      Unknown  ASUS  Oriental Store
# freq            184            3   428            5041
#
#                                                       url  \
# count                                                5041
# unique                                               5041
# top     https://os-jo.com/asus-expertcenter-d5-mini-to...
# freq                                                    1
#
#                                                 image_url   price  \
# count                                                5034  5038.0
# unique                                               4419   358.0
# top     https://os-jo.com/image/cache/catalog/products...    99.0
# freq                                                   23   133.0
#
#         original_price currency in_stock product_description  \
# count           1117.0     5041     5041                4067
# unique           243.0        2        2                 459
# top               99.0      JOD    False             Unknown
# freq              31.0     5038     3796                3501
#
#                                                categories specs
# count                                                5041  5041
# unique                                                 81  3846
# top     {'Gaming PC', 'AMD', 'Gaming PC, Gaming Laptop...    {}
# freq                                                  377   734

# %%
valid_df = df[df['in_stock'] == True].copy()

# %%
valid_df.describe()
# Out:
#        product_code                                       product_name  \
# count          1245                                               1245
# unique         1143                                               1245
# top        OS BUILD  ASUS ExpertCenter D5 Mini Tower (D501MER) Busi...
# freq             21                                                  1
#
#           brand           store  \
# count      1245            1245
# unique       53               1
# top     Unknown  Oriental Store
# freq        146            1245
#
#                                                       url  \
# count                                                1245
# unique                                               1245
# top     https://os-jo.com/asus-expertcenter-d5-mini-to...
# freq                                                    1
#
#                                                 image_url   price  \
# count                                                1245  1245.0
# unique                                               1119   185.0
# top     https://os-jo.com/image/cache/catalog/products...    25.0
# freq                                                   13    42.0
#
#         original_price currency in_stock product_description  \
# count            111.0     1245     1245                 836
# unique            72.0        1        1                 206
# top              199.0      JOD     True             Unknown
# freq               5.0     1245     1245                 603
#
#                                                categories specs
# count                                                1245  1245
# unique                                                 46   797
# top     {'Cooler Master', 'Keyboard & Mouse', 'GLORIOU...    {}
# freq                                                   99   353

# %%
# pd.set_option('future.no_silent_downcasting', True)

# %%
valid_df['original_price'] = valid_df['original_price'].fillna(valid_df['price'])

# %%
valid_df['original_price'][0]
# Out:
# 599.0

# %%
valid_df.describe()
# Out:
#        product_code                                       product_name  \
# count          1245                                               1245
# unique         1143                                               1245
# top        OS BUILD  ASUS ExpertCenter D5 Mini Tower (D501MER) Busi...
# freq             21                                                  1
#
#           brand           store  \
# count      1245            1245
# unique       53               1
# top     Unknown  Oriental Store
# freq        146            1245
#
#                                                       url  \
# count                                                1245
# unique                                               1245
# top     https://os-jo.com/asus-expertcenter-d5-mini-to...
# freq                                                    1
#
#                                                 image_url   price  \
# count                                                1245  1245.0
# unique                                               1119   185.0
# top     https://os-jo.com/image/cache/catalog/products...    25.0
# freq                                                   13    42.0
#
#         original_price currency in_stock product_description  \
# count           1245.0     1245     1245                 836
# unique           181.0        1        1                 206
# top               69.0      JOD     True             Unknown
# freq              41.0     1245     1245                 603
#
#                                                categories specs
# count                                                1245  1245
# unique                                                 46   797
# top     {'Cooler Master', 'Keyboard & Mouse', 'GLORIOU...    {}
# freq                                                   99   353

# %%
str.islow

# %%
valid_df[~valid_df['product_code'].str.isupper()]
# Out:
#                   product_code  \
# 5           Dell Tower ECT1250
# 7     OptiPlex Tower Plus 7020
# 8                Mac Pro Tower
# 10    OptiPlex Tower Plus 7020
# 13      Apple iMac 24" M3 Chip
# ...                        ...
# 4949     Logitech G304 (White)
# 4950     Logitech G304 (Black)
# 4951       Logitech G102 White
# 4953      Logitech BRIO 4K PRO
# 4954            Logitech G102
#
#                                            product_name     brand  \
# 5     Dell Tower ECT1250, Micro Tower Business Deskt...      Dell
# 7     Dell OptiPlex Tower Plus 7020 Business Desktop...      Dell
# 8     Apple Mac Pro Tower Enclosure, Apple M2 Ultra ...     Apple
# 10    Dell OptiPlex Tower Plus 7020 Business Desktop...      Dell
# 13    Apple iMac 24" with Retina 4.5K display Apple ...     Apple
# ...                                                 ...       ...
# 4949  Logitech G304 Lightspeed Wireless (2.4GHz) Gam...  Logitech
# 4950  Logitech G304 Lightspeed Wireless (2.4GHz) Gam...  Logitech
# 4951  Logitech G102 Customizable Wired RGB Mouse, 6 ...  Logitech
# 4953  Logitech BRIO 4K Stream Edition HDR & Autofocu...  Logitech
# 4954  Logitech G102 Customizable Wired RGB Mouse, 6 ...  Logitech
#
#                store                                                url  \
# 5     Oriental Store  https://os-jo.com/dell-tower-ect1250-micro-tow...
# 7     Oriental Store  https://os-jo.com/dell-optiplex-tower-plus-702...
# 8     Oriental Store  https://os-jo.com/apple-mac-pro-tower-enclosur...
# 10    Oriental Store  https://os-jo.com/dell-optiplex-tower-plus-702...
# 13    Oriental Store  https://os-jo.com/apple-imac-24-with-retina-4-...
# ...              ...                                                ...
# 4949  Oriental Store  https://os-jo.com/logitech-g304-lightspeed-wir...
# 4950  Oriental Store  https://os-jo.com/logitech-g304-lightspeed-wir...
# 4951  Oriental Store  https://os-jo.com/logitech-g102-customizable-r...
# 4953  Oriental Store  https://os-jo.com/logitech-brio-4k-stream-edit...
# 4954  Oriental Store  https://os-jo.com/logitech-g102-customizable-r...
#
#                                               image_url   price  \
# 5     https://os-jo.com/image/cache/catalog/products...   349.0
# 7     https://os-jo.com/image/cache/catalog/products...   529.0
# 8     https://os-jo.com/image/cache/catalog/products...  5999.0
# 10    https://os-jo.com/image/cache/catalog/products...   649.0
# 13    https://os-jo.com/image/cache/catalog/products...  1589.0
# ...                                                 ...     ...
# 4949  https://os-jo.com/image/cache/catalog/products...    30.0
# 4950  https://os-jo.com/image/cache/catalog/products...    30.0
# 4951  https://os-jo.com/image/cache/catalog/products...    17.0
# 4953  https://os-jo.com/image/cache/catalog/products...   159.0
# 4954  https://os-jo.com/image/cache/catalog/products...    17.0
#
#      original_price currency  in_stock product_description  \
# 5             349.0      JOD      True             Unknown
# 7             529.0      JOD      True             Unknown
# 8            5999.0      JOD      True             Unknown
# 10            649.0      JOD      True             Unknown
# 13           1589.0      JOD      True             Unknown
# ...             ...      ...       ...                 ...
# 4949           30.0      JOD      True             Unknown
# 4950           30.0      JOD      True             Unknown
# 4951           17.0      JOD      True             Unknown
# 4953          159.0      JOD      True             Unknown
# 4954           17.0      JOD      True             Unknown
#
#                                              categories  \
# 5     {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
# 7     {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
# 8     {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
# 10    {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
# 13    {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
# ...                                                 ...
# 4949  {'Logitech', 'RAZER', 'Gaming PC, Gaming Lapto...
# 4950  {'Logitech', 'RAZER', 'Gaming PC, Gaming Lapto...
# 4951  {'Logitech', 'RAZER', 'Gaming PC, Gaming Lapto...
# 4953  {'Logitech', 'Gaming PC, Gaming Laptop and Gam...
# 4954  {'Logitech', 'Gaming PC, Gaming Laptop and Gam...
#
#                                                   specs
# 5     {'Processor Type': 'Core i3', 'Processor Gener...
# 7     {'Processor Type': 'Core i5', 'Processor Gener...
# 8     {'Processor Type': 'Apple M2 Ultra', 'Processo...
# 10    {'Processor Type': 'Core i7', 'Processor Gener...
# 13    {'Processor Type': 'Apple M3', 'Processor Gene...
# ...                                                 ...
# 4949  {'Full Product Specifications': '• PHYSICAL SP...
# 4950  {'Full Product Specifications': '• PHYSICAL SP...
# 4951  {'Full Product Specifications': '• PHYSICAL SP...
# 4953  {'Full Product Specifications': '•DIMENSIONS:H...
# 4954  {'Full Product Specifications': '• PHYSICAL SP...
#
# [455 rows x 13 columns]

# %%
valid_df['product_name'] = valid_df['product_name'].str.lower()

# %%
valid_df['brand'] = valid_df['brand'].str.lower()

# %%
valid_df.head()
# Out:
#          product_code                                       product_name  \
# 0             D501MER  asus expertcenter d5 mini tower (d501mer) busi...
# 1             B5TQ8AA  hp omnidesk desktop pc (m02-0234) amd ryzen 7 ...
# 2             BE8B1AA  hp omen 35l gaming pc (dt gt16-0344) (pre-buil...
# 3             BC4K6AA  hp omen 16l gaming pc (dt tg03-0154) (pre-buil...
# 4  1M-285BJO-B3100UXX  msi cubi 1m mini pc, portable mini pc desktop,...
#
#   brand           store                                                url  \
# 0  asus  Oriental Store  https://os-jo.com/asus-expertcenter-d5-mini-to...
# 1    hp  Oriental Store  https://os-jo.com/hp-omnidesk-desktop-pc-m02-0...
# 2    hp  Oriental Store  https://os-jo.com/hp-omen-35l-gaming-pc-dt-gt1...
# 3    hp  Oriental Store  https://os-jo.com/hp-omen-16l-gaming-pc-dt-tg0...
# 4   msi  Oriental Store  https://os-jo.com/msi-cubi-1m-mini-pc-portable...
#
#                                            image_url   price original_price  \
# 0  https://os-jo.com/image/cache/catalog/products...   599.0          599.0
# 1  https://os-jo.com/image/cache/catalog/products...   629.0          629.0
# 2  https://os-jo.com/image/cache/catalog/products...  1169.0         1169.0
# 3  https://os-jo.com/image/cache/catalog/products...   929.0          929.0
# 4  https://os-jo.com/image/cache/catalog/products...   259.0          259.0
#
#   currency  in_stock product_description  \
# 0      JOD      True             Unknown
# 1      JOD      True             Unknown
# 2      JOD      True             Unknown
# 3      JOD      True             Unknown
# 4      JOD      True             Unknown
#
#                                           categories  \
# 0  {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
# 1  {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
# 2  {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
# 3  {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
# 4  {'Apple', 'Lenovo', 'Computer Systems', 'Dell'...
#
#                                                specs
# 0  {'Processor Type': 'Core i7', 'Processor Gener...
# 1  {'Processor Type': 'AMD', 'Processor Generatio...
# 2  {'Processor': 'AMD RYZEN 7 8700F', 'Motherboar...
# 3  {'Processor': 'INTEL CORE I5 14400F', 'Motherb...
# 4  {'Processor Type': 'Core 3', 'Processor Genera...

# %%
t = valid_df['specs'].loc[0]

# %%
t
# Out:
# "{'Processor Type': 'Core i7', 'Processor Generation': '14th Generation', 'Processor Family': 'i7-14700', 'Processor Speed': 'Up To 5.4GHz', 'Processor Cache': '33MB', 'Processor Cores': '20 (8P+12E)', 'Processor Threads': '28 Threads', 'Memory Size': '8GB (1 X 8GB)', 'Memory Type': 'DDR5', 'Number of Memory Slot': '2', 'Storage Technology': 'M.2 PCIe NVMe SSD PCIe 4.0', 'Storage Capacity': '512GB', 'Graphic Manufacturer': 'Intel', 'Graphic Chip-set Model': 'Intel® UHD Graphics 770', 'Graphic Memory Size': 'Shared Memory', 'Graphic Memory Type': 'Integrated Memory', 'Optical Drive': 'No', 'Ports': '*Front I/O Ports  1x Smart card reader  1x 2 in 1 card reader SD / MMC  2x USB 3.2 Gen 2 Type-A  2x USB 2.0 Type-A  1x 3.5mm combo audio jack  1x Headphone  *Rear I/O Ports  2x USB 3.2 Gen 1 Type-A  2x USB 2.0 Type-A  1x Padlock loop  1x Kensington lock  1x 7.1 channel audio (microphone  line-out  Line-in)  1x VGA Port  1x HDMI 1.4  1x RJ45 Gigabit Ethernet', 'Audio': 'High Definition 7.1 Channel Audio', 'Included Operating System': 'Free DOS', 'Communications': 'RJ45 Gigabit Ethernet 10/100/1000  Wi-Fi 6(802.11ax) (Dual band) 2*2 + Bluetooth® 5.4 Wireless Card', 'Accessories': 'Wired Keyboard + Mouse', 'Warranty': '1 Year', 'Chipset': 'Intel® B760 Chipset'}"

# %%
len(t)
# Out:
# 1271

# %%
type(t)a
# Out:
# str

# %%
e = ast.literal_eval(t)

# %%
q = ' '.join(list(e.values()))

# %%
len(q)
# Out:
# 745

# %%
q
# Out:
# 'Core i7 14th Generation i7-14700 Up To 5.4GHz 33MB 20 (8P+12E) 28 Threads 8GB (1 X 8GB) DDR5 2 M.2 PCIe NVMe SSD PCIe 4.0 512GB Intel Intel® UHD Graphics 770 Shared Memory Integrated Memory No *Front I/O Ports  1x Smart card reader  1x 2 in 1 card reader SD / MMC  2x USB 3.2 Gen 2 Type-A  2x USB 2.0 Type-A  1x 3.5mm combo audio jack  1x Headphone  *Rear I/O Ports  2x USB 3.2 Gen 1 Type-A  2x USB 2.0 Type-A  1x Padlock loop  1x Kensington lock  1x 7.1 channel audio (microphone  line-out  Line-in)  1x VGA Port  1x HDMI 1.4  1x RJ45 Gigabit Ethernet High Definition 7.1 Channel Audio Free DOS RJ45 Gigabit Ethernet 10/100/1000  Wi-Fi 6(802.11ax) (Dual band) 2*2 + Bluetooth® 5.4 Wireless Card Wired Keyboard + Mouse 1 Year Intel® B760 Chipset'
