# %%
import pandas as pd
import json

# %%
df = pd.read_csv('../../data/compujordan/compujordan_crawl.csv', index_col=0)

# %%
df.head()
# Out:
#                                                 urls  \
# 0  https://compujordan.com/intel-core-ultra-7-265...
# 1  https://compujordan.com/gigabyte-z890-gaming-x...
# 2  https://compujordan.com/intel-core-i7-14700kf-...
# 3  https://compujordan.com/intel-core-ultra-9-285...
# 4  https://compujordan.com/msi-geforce-rtx-5070-t...
#
#                                           categories
# 0  {'Computer Hardware', 'Gaming Components', 'Ga...
# 1  {'Computer Hardware', 'Gaming Components', 'Ga...
# 2  {'Computer Hardware', 'Gaming Components', 'Ga...
# 3  {'Computer Hardware', 'Gaming Components', 'Ga...
# 4  {'Computer Hardware', 'Gaming Components', 'Ga...

# %%
js = df.to_json()

# %%
# Out:
# '{"urls":{"0":"https:\\/\\/compujordan.com\\/intel-core-ultra-7-265k-20-core-processor-box-lga1851-up-to-5-5ghz","1":"https:\\/\\/compujordan.com\\/gigabyte-z890-gaming-x-wi-fi-7-bluetooth-ddr5-atx-motherboard-lga1851-intel-core-ultra-series-2","2":"https:\\/\\/compujordan.com\\/intel-core-i7-14700kf-14th-gen-unlocked-cpu-processor-20-cores-8p-12e-28-threads-up-to-5-6ghz-lga1700-tray","3":"https:\\/\\/compujordan.com\\/intel-core-ultra-9-285k-series-2-24-core-24-thread-processor-up-to-5-70ghz-lga1851-tray","4":"https:\\/\\/compujordan.com\\/msi-geforce-rtx-5070-ti-16g-shadow-3x-oc-16gb-gddr7-graphics-card","5":"https:\\/\\/compujordan.com\\/aerocool-mirage-gold-850w-argb-fully-modular-80-plus-gold-power-supply-with-infinity-mirror-design","6":"https:\\/\\/compujordan.com\\/deepcool-cg530-4f-panoramic-atx-mid-tower-case-white-tempered-glass-4x-argb-fans","7":"https:\\/\\/compujordan.com\\/deepcool-cg530-4f-panoramic-atx-mid-tower-case-black-tempered-glass-4x-argb-fans","8":"https:\\/\
# ...
