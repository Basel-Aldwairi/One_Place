# %%
import pandas as pd

# %%
file = '../../../data/compujordan/compujordan_products.csv'

# %%
df = pd.read_csv(file, index_col=0)

# %%
df.describe()
# Out:
#        product_code                                       product_name  \
# count          2977                                               2977
# unique         2960                                               2973
# top            3593  Lenovo V14-ADA AMD Ryzen 3 3250u - Business La...
# freq              3                                                  2
#
#            brand         store  \
# count       2977          2976
# unique       101             2
# top     Logitech  Compu Jordan
# freq         266          2975
#
#                                                       url  \
# count                                                2975
# unique                                               2975
# top     https://compujordan.com/intel-core-ultra-7-265...
# freq                                                    1
#
#                                                 image_url price  \
# count                                                2976  2976
# ...

# %%
for i in range(3):
    print(df[df['product_code'] == '3593']['url'].iloc[i])
# Out:
# https://compujordan.com/dell-inspiron-3593-ci7-4g-core-i7-1065g7-laptop
# https://compujordan.com/dell-inspiron-3593-ci7-core-i7-1065g7-laptop
# https://compujordan.com/dell-inspiron-3593-ci5-core-i5-1035g1-laptop

# %%
df['url'].iloc[0]
# Out:
# 'https://compujordan.com/intel-core-ultra-7-265k-20-core-processor-box-lga1851-up-to-5-5ghz'

# %%
df.head()
# Out:
#                    product_code  \
# 0                  Ultra 7 265K
# 1           Z890 GAMING X WIFI7
# 2                    i7-14700KF
# 3             Core Ultra 9 285K
# 4  RTX 5070 Ti 16G SHADOW 3X OC
#
#                                         product_name     brand         store  \
# 0  Intel Core Ultra 7 265K – 20-Core Processor (B...     Intel  Compu Jordan
# 1  GIGABYTE Z890 Gaming X Wi-Fi 7 & Bluetooth DDR...  GIGABYTE  Compu Jordan
# 2  Intel Core i7-14700KF – 14th Gen Unlocked CPU ...     Intel  Compu Jordan
# 3  Intel Core Ultra 9 285K (Series 2) – 24-Core, ...     Intel  Compu Jordan
# 4  MSI GeForce RTX 5070 Ti 16G SHADOW 3X OC – 16G...       MSI  Compu Jordan
#
#                                                  url  \
# 0  https://compujordan.com/intel-core-ultra-7-265...
# 1  https://compujordan.com/gigabyte-z890-gaming-x...
# 2  https://compujordan.com/intel-core-i7-14700kf-...
# 3  https://compujordan.com/intel-core-ultra-9-285...
# ...

# %%
valid_df = df[df['in_stock'] == 'True']

# %%
valid_df.describe()
# Out:
#         product_code                                       product_name  \
# count            864                                                864
# unique           864                                                863
# top     Ultra 7 265K  Lenovo V14-ADA AMD Ryzen 3 3250u - Business La...
# freq               1                                                  2
#
#         brand         store  \
# count     864           864
# unique     67             1
# top     HAVIT  Compu Jordan
# freq      163           864
#
#                                                       url  \
# count                                                 864
# unique                                                864
# top     https://compujordan.com/intel-core-ultra-7-265...
# freq                                                    1
#
#                                                 image_url price  \
# count                                                 864   864
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2977 entries, 0 to 2975
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_code         2977 non-null   object
#  1   product_name         2977 non-null   object
#  2   brand                2977 non-null   object
#  3   store                2976 non-null   object
#  4   url                  2975 non-null   object
#  5   image_url            2976 non-null   object
#  6   price                2976 non-null   object
#  7   original_price       249 non-null    object
#  8   currency             2976 non-null   object
#  9   in_stock             2976 non-null   object
#  10  product_description  2632 non-null   object
#  11  categories           2975 non-null   object
#  12  specs                2975 non-null   object
# dtypes: object(13)
# memory usage: 390.1+ KB
