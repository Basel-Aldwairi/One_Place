# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
from collections import deque

# %%
start = 'https://citycenter.jo/product/search?search=%20&page=1'

# %%
# response = requests.get(link)

# %%
# soup = BeautifulSoup(response.text, parser='lxml',features='lxml')

# %%
# all_as = soup.find_all('a', href=True)
# a = soup.find('a', href=True)

# %%
# patterns = [
#     'citycenter.jo/pc-and-laptops',
#     'citycenter.jo/computer-hardware-monitor-and-display',
#     'citycenter.jo/computer-hardware-peripherals',
#     'citycenter.jo/computer-hardware-audio',
#     'citycenter.jo/computer-hardware-storage',
#     'citycenter.jo/computer-hardware',
#     'citycenter.jo/gaming',
#     'citycenter.jo/peripherals-printer-and-scanner',
#     'citycenter.jo/electronics',
#     'citycenter.jo/Networking'
# ]

patterns = ['https://citycenter.jo/',
    'https://citycenter.jo/product/search?search']

# %%
# visited = set()
# queue = []
# visited.add(start)
# queue.append(start)
# max_depth = 20

# %%
visited = set()
queue = deque()
visited.add(start)
queue.append(start)
max_depth = 100
start_time = time.time()
num_links_found = 1

current_depth = 0
print(f'[INFO] : start with link#{start}')

while queue and current_depth < max_depth:
    current_link = queue.popleft()
    current_depth += 1
    response = requests.get(start)
    new_link_found = False
    print(f'[INFO] : depth = {current_depth} / {max_depth} : {current_link}')
    soup = BeautifulSoup(response.text, parser='lxml',features='lxml')

    all_links = soup.find_all('a', href=True)

    for link_text in all_links:
        link = link_text.get_attribute_list('href')[0]
        # print(link)
        valid_link = patterns[0] in link
        search_link = patterns[1] in link
        
        if valid_link and link not in visited:
            num_links_found += 1
            visited.add(link)
            print(f'[INFO depth = {current_depth} / {max_depth}] : link #{num_links_found} : {link}')
            new_link_found = True
            if search_link:
                queue.append(link)
                

    if not new_link_found:
        current_depth -= 1
        
        # print(valid_link, link)
        # if valid_link and link not in visited:
        #     num_links_found += 1
        #     visited.add(link)
        #     queue.append(link)

finish_time = time.time() - start_time
print(f'[INFO] : finished in {finish_time:.2f}')
# Out:
# [INFO] : start with link#https://citycenter.jo/product/search?search=%20&page=1
# [INFO] : depth = 1 / 100 : https://citycenter.jo/product/search?search=%20&page=1
# [INFO depth = 1 / 100] : link #2 : https://citycenter.jo/account/account
# [INFO depth = 1 / 100] : link #3 : https://citycenter.jo/account/login
# [INFO depth = 1 / 100] : link #4 : https://citycenter.jo/account/register
# [INFO depth = 1 / 100] : link #5 : https://citycenter.jo/account/order
# [INFO depth = 1 / 100] : link #6 : https://citycenter.jo/account/wishlist
# [INFO depth = 1 / 100] : link #7 : https://citycenter.jo/account/address
# [INFO depth = 1 / 100] : link #8 : https://citycenter.jo/account/download
# [INFO depth = 1 / 100] : link #9 : https://citycenter.jo/account/transaction
# [INFO depth = 1 / 100] : link #10 : https://citycenter.jo/account/logout
# [INFO depth = 1 / 100] : link #11 : https://citycenter.jo/product/compare
# [INFO depth = 1 / 100] : link #12 : https://citycenter.jo/checkout/cart
# [INFO depth = 1 / 100] : link #13 : https://citycenter.jo/pc-and-laptops
# [INFO depth = 1 / 100] : link #14 : https://citycenter.jo/computer-hardware-monitor-and-display
# [INFO depth = 1 / 100] : link #15 : https://citycenter.jo//computer-hardware-peripherals
# [INFO depth = 1 / 100] : link #16 : https://citycenter.jo/computer-hardware-audio
# [INFO depth = 1 / 100] : link #17 : https://citycenter.jo/computer-hardware-storage
# [INFO depth = 1 / 100] : link #18 : https://citycenter.jo/computer-hardware
# [INFO depth = 1 / 100] : link #19 : https://citycenter.jo/gaming
# [INFO depth = 1 / 100] : link #20 : https://citycenter.jo/computer-hardware/computer-hardware-monitor-and-display
# [INFO depth = 1 / 100] : link #21 : https://citycenter.jo/peripherals-printer-and-scanner
# [INFO depth = 1 / 100] : link #22 : https://citycenter.jo/electronics
# [INFO depth = 1 / 100] : link #23 : https://citycenter.jo/Networking
# [INFO depth = 1 / 100] : link #24 : https://citycenter.jo/pc-and-laptops/computer-hardware-server-and-workstation
# [INFO depth = 1 / 100] : link #25 : https://citycenter.jo/pc-and-laptops/tablet-accessories
# [INFO depth = 1 / 100] : link #26 : https://citycenter.jo/pc-and-laptops/software
# [INFO depth = 1 / 100] : link #27 : https://citycenter.jo/computer-hardware/components-cpu-and-processor
# [INFO depth = 1 / 100] : link #28 : https://citycenter.jo/computer-hardware/components-fan-and-heatsink
# [INFO depth = 1 / 100] : link #29 : https://citycenter.jo/computer-hardware/components-motherboard
# [INFO depth = 1 / 100] : link #30 : https://citycenter.jo/computer-hardware/components-memory-ram
# [INFO depth = 1 / 100] : link #31 : https://citycenter.jo/computer-hardware/components-video-card
# [INFO depth = 1 / 100] : link #32 : https://citycenter.jo/computer-hardware/components-case-and-chassis
# [INFO depth = 1 / 100] : link #33 : https://citycenter.jo/computer-hardware/components-power-supply
# [INFO depth = 1 / 100] : link #34 : https://citycenter.jo/computer-hardware/components-hard-drive
# [INFO depth = 1 / 100] : link #35 : https://citycenter.jo/computer-hardware/components-blu-ray-dvd-drives
# [INFO depth = 1 / 100] : link #36 : https://citycenter.jo/computer-hardware/components-solid-state-drive-ssd
# [INFO depth = 1 / 100] : link #37 : https://citycenter.jo/computer-hardware/components-pcipci-e-add-card
# [INFO depth = 1 / 100] : link #38 : https://citycenter.jo/gaming/gaming-desk
# [INFO depth = 1 / 100] : link #39 : https://citycenter.jo/computer-hardware-monitor-and-display/ch-gaming-monitors
# [INFO depth = 1 / 100] : link #40 : https://citycenter.jo/computer-hardware-monitor-and-display/monitor-and-display-1415-lcdled-monitor
# [INFO depth = 1 / 100] : link #41 : https://citycenter.jo/computer-hardware-monitor-and-display/portable-monitors
# [INFO depth = 1 / 100] : link #42 : https://citycenter.jo/computer-hardware-monitor-and-display/lcd-led-monitors
# [INFO depth = 1 / 100] : link #43 : https://citycenter.jo/computer-hardware-peripherals/gaming-desks
# [INFO depth = 1 / 100] : link #44 : https://citycenter.jo/computer-hardware-peripherals/stream-equipment
# [INFO depth = 1 / 100] : link #45 : https://citycenter.jo/computer-hardware-peripherals/peripherals-cable
# [INFO depth = 1 / 100] : link #46 : https://citycenter.jo/computer-hardware-peripherals/peripherals-power-protection-and-ups
# [INFO depth = 1 / 100] : link #47 : https://citycenter.jo/computer-hardware-peripherals/peripherals-combo
# [INFO depth = 1 / 100] : link #48 : https://citycenter.jo/computer-hardware-peripherals/peripherals-keyboard
# [INFO depth = 1 / 100] : link #49 : https://citycenter.jo/computer-hardware-peripherals/peripherals-mouse
# [INFO depth = 1 / 100] : link #50 : https://citycenter.jo/computer-hardware-peripherals/peripherals-mouse-pad
# [INFO depth = 1 / 100] : link #51 : https://citycenter.jo/computer-hardware-peripherals/peripherals-gaming-accessories
# [INFO depth = 1 / 100] : link #52 : https://citycenter.jo/computer-hardware-peripherals/gaming-chairs
# [INFO depth = 1 / 100] : link #53 : https://citycenter.jo/computer-hardware-peripherals/peripherals-gaming-controller
# [INFO depth = 1 / 100] : link #54 : https://citycenter.jo/computer-hardware-peripherals/peripherals-graphics-tablet
# [INFO depth = 1 / 100] : link #55 : https://citycenter.jo/computer-hardware-peripherals/peripherals-wireless-pointer
# [INFO depth = 1 / 100] : link #56 : https://citycenter.jo/computer-hardware-peripherals/peripherals-webcam
# [INFO depth = 1 / 100] : link #57 : https://citycenter.jo/computer-hardware-audio/audio-mic
# [INFO depth = 1 / 100] : link #58 : https://citycenter.jo/computer-hardware-audio/audio-multimedia-player
# [INFO depth = 1 / 100] : link #59 : https://citycenter.jo/computer-hardware-audio/audio-sound-card
# [INFO depth = 1 / 100] : link #60 : https://citycenter.jo/computer-hardware-audio/audio-sound-pars
# [INFO depth = 1 / 100] : link #61 : https://citycenter.jo/computer-hardware-audio/audio-speaker-and-headset
# [INFO depth = 1 / 100] : link #62 : https://citycenter.jo/computer-hardware-storage/ssds-solid-state-drive
# [INFO depth = 1 / 100] : link #63 : https://citycenter.jo/computer-hardware-storage/internal-external-hdds
# [INFO depth = 1 / 100] : link #64 : https://citycenter.jo/computer-hardware-storage/blu-ray-dvd-drives
# [INFO depth = 1 / 100] : link #65 : https://citycenter.jo/computer-hardware-storage/storage-nas
# [INFO depth = 1 / 100] : link #66 : https://citycenter.jo/computer-hardware-storage/storage-external-enclosure
# [INFO depth = 1 / 100] : link #67 : https://citycenter.jo/computer-hardware-storage/storage-usb-pendrive
# [INFO depth = 1 / 100] : link #68 : https://citycenter.jo/computer-hardware-storage/storage-memory-card
# [INFO depth = 1 / 100] : link #69 : https://citycenter.jo/peripherals-printer-and-scanner/dot-matrix
# [INFO depth = 1 / 100] : link #70 : https://citycenter.jo/electronics/electronics-camera
# [INFO depth = 1 / 100] : link #71 : https://citycenter.jo/electronics/office-products
# [INFO depth = 1 / 100] : link #72 : https://citycenter.jo/electronics/electronics-point-sale
# [INFO depth = 1 / 100] : link #73 : https://citycenter.jo/electronics/computer-hardware-projector-and-screen
# [INFO depth = 1 / 100] : link #74 : https://citycenter.jo/electronics/electronics-security-and-surveillance
# [INFO depth = 1 / 100] : link #75 : https://citycenter.jo/electronics/electronics-smart-home
# [INFO depth = 1 / 100] : link #76 : https://citycenter.jo/electronics/electronics-smartphone
# [INFO depth = 1 / 100] : link #77 : https://citycenter.jo/electronics/electronics-wearable-device
# [INFO depth = 1 / 100] : link #78 : https://citycenter.jo/networking/wireless-network
# [INFO depth = 1 / 100] : link #79 : https://citycenter.jo/networking/wired-network
# [INFO depth = 1 / 100] : link #80 : https://citycenter.jo/networking/3g-4g-routers
# [INFO depth = 1 / 100] : link #81 : https://citycenter.jo/networking/powerline-adapter
# [INFO depth = 1 / 100] : link #82 : https://citycenter.jo/
# [INFO depth = 1 / 100] : link #83 : https://citycenter.jo/1more-sonoflow-hc905-active-noise-cancelling-headphones-bluetooth-headphones-with-ldac-for-hi-res-wireless-audio-70h-playtime-clear-calls-preset-eq-via-app-black?search=%20&page=1
# [INFO depth = 1 / 100] : link #84 : https://citycenter.jo/1more-sonoflow-hc905-active-noise-cancelling-headphones-bluetooth-headphones-with-ldac-for-hi-res-wireless-audio-70h-playtime-clear-calls-preset-eq-via-app-blue?search=%20&page=1
# [INFO depth = 1 / 100] : link #85 : https://citycenter.jo/1more-sonoflow-hc905-active-noise-cancelling-headphones-bluetooth-headphones-with-ldac-for-hi-res-wireless-audio-70h-playtime-clear-calls-preset-eq-via-app-silver?search=%20&page=1
# [INFO depth = 1 / 100] : link #86 : https://citycenter.jo/360-degree-photo-booth-machine-with-rgb-light-flight-case-360-camera-booth-with-flight-case-for-parties-360-degree-automatic-rotating-photobooth-115cm?search=%20&page=1
# [INFO depth = 1 / 100] : link #87 : https://citycenter.jo/360-degree-photo-booth-machine-with-rgb-light-flight-case-360-camera-booth-with-flight-case-for-parties-360-degree-automatic-rotating-photobooth-80cm?search=%20&page=1
# [INFO depth = 1 / 100] : link #88 : https://citycenter.jo/acefast-c1-01-usb-c-to-lightning-plug-mfi-certified-fast-charging-and-data-transmittion-cable-pd-30w-3a-1-2m-aluminum-alloy-compatbile-with-iphone-13-12-11-ipad-airpods-deep-grey?search=%20&page=1
# [INFO depth = 1 / 100] : link #89 : https://citycenter.jo/acefast-c3-01-usb-c-to-lightning-tpe-charging-data-cable-1-2m-white?search=%20&page=1
# [INFO depth = 1 / 100] : link #90 : https://citycenter.jo/acefast-c3-03-usb-c-to-usb-c-tpe-charging-data-cable-1-2m-white?search=%20&page=1
# [INFO depth = 1 / 100] : link #91 : https://citycenter.jo/acefast-d18-in-car-2-in-1-magsafe-qi-inductive-mobile-and-iwatch-wireless-charging-car-holder-convenient-fast-and-efficient-2-5w-5w-7-5w-10w-15w-output-black?search=%20&page=1
# [INFO depth = 1 / 100] : link #92 : https://citycenter.jo/acefast-d37-car-dashboard-magnetic-wireless-charger-phone-mount-holder?search=%20&page=1
# [INFO depth = 1 / 100] : link #93 : https://citycenter.jo/acefast-e19-qi2-3-in-1-desktop-wireless-charging-holder-magnetic-wireless-charger-for-phone-tws-headset-smart-watch-compatible-with-all-iphone-mobile-black?search=%20&page=1
# [INFO depth = 1 / 100] : link #94 : https://citycenter.jo/acefast-m23-power-bank-10000mah-built-in-dual-cables-22-5w-fast-charging-portable-charger-black?search=%20&page=1
# [INFO depth = 1 / 100] : link #95 : https://citycenter.jo/acefast-manual-vacuum-suction-cup-magnetic-car-phone-holder-for-iphone-16-15-pro-hands-free-360-rotation-adjustable-phone-stand?search=%20&page=1
# [INFO depth = 1 / 100] : link #96 : https://citycenter.jo/acefast-n1-enc-calling-noise-reduction-neckband-wireless-headphones-hifi-stereo-neckband-music-earphone-with-microphone?search=%20&page=1
# [INFO depth = 1 / 100] : link #97 : https://citycenter.jo/acefast-r1-wireless-lavalier-dual-microphone-for-iphone-android-usb-c-360-omnidirectional-deep-ai-noise-cancellation-black?search=%20&page=1
# [INFO depth = 1 / 100] : link #98 : https://citycenter.jo/acefast-r2-wireless-lavalier-dual-microphone-for-iphone-android-usb-c-ai-noise-reduction-low-latency-lossless-sound-mics-black?search=%20&page=1
# [INFO depth = 1 / 100] : link #99 : https://citycenter.jo/product/search?search=%20&page=2
# [INFO depth = 1 / 100] : link #100 : https://citycenter.jo/product/search?search=%20&page=3
# [INFO depth = 1 / 100] : link #101 : https://citycenter.jo/product/search?search=%20&page=4
# [INFO depth = 1 / 100] : link #102 : https://citycenter.jo/product/search?search=%20&page=5
# [INFO depth = 1 / 100] : link #103 : https://citycenter.jo/product/search?search=%20&page=6
# [INFO depth = 1 / 100] : link #104 : https://citycenter.jo/product/search?search=%20&page=7
# [INFO depth = 1 / 100] : link #105 : https://citycenter.jo/product/search?search=%20&page=8
# [INFO depth = 1 / 100] : link #106 : https://citycenter.jo/product/search?search=%20&page=9
# [INFO depth = 1 / 100] : link #107 : https://citycenter.jo/product/search?search=%20&page=477
# [INFO depth = 1 / 100] : link #108 : https://citycenter.jo/about-us
# [INFO depth = 1 / 100] : link #109 : https://citycenter.jo/delivery-information
# [INFO depth = 1 / 100] : link #110 : https://citycenter.jo/privacy-policy
# [INFO depth = 1 / 100] : link #111 : https://citycenter.jo/terms-conditions
# [INFO depth = 1 / 100] : link #112 : https://citycenter.jo/information/contact
# [INFO depth = 1 / 100] : link #113 : https://citycenter.jo/information/sitemap
# [INFO depth = 1 / 100] : link #114 : https://citycenter.jo/service-center
# [INFO depth = 1 / 100] : link #115 : https://citycenter.jo/product/manufacturer
# [INFO depth = 1 / 100] : link #116 : https://citycenter.jo/product/special
# [INFO depth = 1 / 100] : link #117 : https://citycenter.jo/account/newsletter
# [INFO] : depth = 2 / 100 : https://citycenter.jo/product/search?search=%20&page=2
# [INFO] : depth = 2 / 100 : https://citycenter.jo/product/search?search=%20&page=3
# [INFO] : depth = 2 / 100 : https://citycenter.jo/product/search?search=%20&page=4
# [INFO] : depth = 2 / 100 : https://citycenter.jo/product/search?search=%20&page=5
# [INFO] : depth = 2 / 100 : https://citycenter.jo/product/search?search=%20&page=6
# [INFO] : depth = 2 / 100 : https://citycenter.jo/product/search?search=%20&page=7
# [INFO] : depth = 2 / 100 : https://citycenter.jo/product/search?search=%20&page=8
# [INFO] : depth = 2 / 100 : https://citycenter.jo/product/search?search=%20&page=9
# [INFO] : depth = 2 / 100 : https://citycenter.jo/product/search?search=%20&page=477
# [INFO] : finished in 20.92

# %%
def pattern_exists(link,pattern):
    return pattern in link

# %%
# for a in all_as:
#     link = a.get_attribute_list('href')[0]

#     valid_link = 'citycenter.jo' in link
#     valid_sub = any([pattern_exists(link,pattern) for pattern in patterns])
#     if valid_link:
#         if valid_sub and link not in visited:
#             visited.add(link)
#             queue.append(link)

# %%
len(visited)
# Out:
# 117

# %%
all_found_links = list(visited)

# %%
df_dict = {
    'Links' : all_found_links
}

# %%
df = pd.DataFrame(df_dict)

# %%
df.head()
# Out:
#                                                Links
# 0  https://citycenter.jo/computer-hardware-periph...
# 1  https://citycenter.jo/acefast-c3-03-usb-c-to-u...
# 2  https://citycenter.jo/computer-hardware/compon...
# 3  https://citycenter.jo/computer-hardware-storag...
# 4  https://citycenter.jo/electronics/office-products

# %%
df.to_csv('all_found_links.csv')
