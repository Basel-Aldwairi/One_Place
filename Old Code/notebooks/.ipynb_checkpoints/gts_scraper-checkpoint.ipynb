# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://gts.jo/en/point-of-sale/datalogic-quickscan-qd2590-bk-corded-handheld-omnidirectional-area-imager-barcode-scanner-black-1d-2d-and-postal-codes-without-usb-cable'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, parser='lxml', features='lxml')

# %%
with open('gts_test.html', 'w', encoding='utf-8') as f:
    f.write(soup.prettify())

# %%
name_tag = soup.find('div', class_='tb_wt tb_wt_page_title_system tb_mb_20 display-block tb_system_page_title')

# %%
product_name = name_tag.find('h1').text if name_tag else None

# %%
product_name
# Out:
# 'Datalogic QuickScan QD2590-BK Corded Handheld Omnidirectional Area Imager/Barcode Scanner (Black, 1D, 2D and Postal Codes) Without USB Cable'

# %%
product_code_tag = soup.find('dd', class_='product-info product-info-code product-info-code-value')

# %%
product_tag = product_code_tag.text if product_code_tag else None

# %%
product_tag
# Out:
# 'QD2590'

# %%
product_brand_tag = soup.find('dd', class_='product-info product-info-brand product-info-brand-value')

# %%
product_brand = product_brand_tag.text if product_brand_tag else None

# %%
product_brand
# Out:
# 'DATALOGIC'

# %%
status_availabity_tag = soup.find('span', class_='tb_stock_status_in_stock')

# %%
status_availabity = status_availabity_tag.text if status_availabity_tag else None

# %%
status_availabity
# Out:
# 'In Stock'

# %%
price = None
sale = None
currency = None

# %%
price_tag = soup.find('div', class_='price')

# %%
price_tag.text.strip().split()[1]
# Out:
# '89.00'

# %%
# price_regular_tag = price_tag.find('span', class_='price-regular')
# price

# %%
price_list = price_tag.text.strip().split()
currency = price_list[0]
price = price_list[1]
sale = price_list[3] if len(price_list) > 2 else None

# %%
currency
# Out:
# 'JOD'

# %%
price
# Out:
# '89.00'

# %%
sale

# %%
dfs = pd.read_html(url)

# %%
product_description_table = None

# %%
if len(dfs) > 1:
    df = dfs[1]
    product_description_cat = df.iloc[:,0].to_list()
    product_description_value = df.iloc[:, 1].to_list()
    product_description_table = list(zip(product_description_cat,product_description_value))

# %%
product_description_table

# %%
product_description_list_tag = soup.find('div', class_='panel-body tb_product_description tb_text_wrap')

# %%
product_description_list_items = None
if product_description_list_tag:
    product_description_list_item_tags = product_description_list_tag.find_all('li')    
    product_description_list_items = [li.text.strip() for li in product_description_list_item_tags]

# %%
product_description_list_items
# Out:
# ['High-performance 2D scanning\xa0for retail, loyalty cards, and electronic coupons',
#  "Cordless convenience\xa0with options for Bluetooth® or Datalogic's STAR Cordless System",
#  'Omnidirectional reading\xa0capability for various barcode types',
#  'Intuitive aiming system\xa0with blue LED and high precision feedback',
#  'EASEOFCARE Service Plans\xa0available for long-term investment protection',
#  'Decoding Capability:1D/Linear Codes, 2D Codes, Postal Codes, Stacked Codes, Digital Watermarking',
#  '1D/Linear Codes, 2D Codes, Postal Codes, Stacked Codes, Digital Watermarking',
#  'Communications:QuickScan QM2500: Datalogic STAR Cordless System, Radio Frequencies: 433 MHz or 910 MHzQuickScan QBT2500: Bluetooth® 4.0, Class 1',
#  'QuickScan QM2500: Datalogic STAR Cordless System, Radio Frequencies: 433 MHz or 910 MHz',
#  'QuickScan QBT2500: Bluetooth® 4.0, Class 1',
#  'Reading Performance:Resolution: Up to 1 MegapixelMotion Tolerance: 30 IPS',
#  'Resolution: Up to 1 Megapixel',
#  'Motion Tolerance: 30 IPS',
#  'Electrical:Input Voltage: 5 VDCTypical Operating Current: <400 mA @ 5V',
#  'Input Voltage: 5 VDC',
#  'Typical Operating Current: <400 mA @ 5V',
#  'Environmental:Operating Temperature: 0 to 50 °C / 32 to 122 °FDrop Resistance: Withstands drops from up to 1.5 m / 5.0 ft',
#  'Operating Temperature: 0 to 50 °C / 32 to 122 °F',
#  'Drop Resistance: Withstands drops from up to 1.5 m / 5.0 ft',
#  'Warranty:\xa05-Year Factory Warranty']
