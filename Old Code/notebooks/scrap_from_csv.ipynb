# %%
import pandas as pd

import sys
sys.path.insert(0, "../src")

import city_center_scrap

# %%
df = pd.read_csv('all_found_links_search.csv', index_col=0)

# %%
links_list = df['Links'].to_list()

# %%
scraped = [city_center_scrap.scrap_citycenter(link) for link in links_list]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 scraped = [city_center_scrap.scrap_citycenter(link) for link in links_list]
#
# File ~/PycharmProjects/One_Place/notebooks/../src/city_center_scrap.py:32, in scrap_citycenter(link)
#      30     product_description = product_description_list
#      31 else:
# ---> 32     product_description = soup.find('div', class_='tb_wt tb_wt_product_field_system display-block tb_system_product_field_1').text
#      34 product_info = soup.find('div', class_='tb_wt tb_wt_product_info_system display-inline-block tb_system_product_info')
#      36 product_info_dt = product_info.find_all('dt')
#
# AttributeError: 'NoneType' object has no attribute 'text'
