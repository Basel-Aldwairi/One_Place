# %%
import pandas as pd
from bs4 import BeautifulSoup

# %%
path = '../src/gts/gts_crawl.csv'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0                                                  0
# 0           0  <!DOCTYPE html>\n<html dir="ltr" lang="en">\n<...
# 1           1  <!DOCTYPE html>\n<html dir="ltr" lang="en">\n<...
# 2           2  <!DOCTYPE html>\n<html dir="ltr" lang="en">\n<...
# 3           3  <!DOCTYPE html>\n<html dir="ltr" lang="en">\n<...
# 4           4  <!DOCTYPE html>\n<html dir="ltr" lang="en">\n<...
