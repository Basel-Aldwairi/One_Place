# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
from collections import deque
import re

# %%
start = 'https://citycenter.jo/product/search?search=%20&page=1'

# %%
response = requests.get(start).text
soup = BeautifulSoup(response, parser='lxml',features='lxml')

# %%
max_pages = soup.find('div', class_='results').text

# %%
max_pages = int(re.findall(r'\(.*\)',max_pages)[0][1:-1].split()[0])

# %%
max_pages
# Out:
# 477

# %%
# response = requests.get(link)

# %%
# soup = BeautifulSoup(response.text, parser='lxml',features='lxml')

# %%
# all_as = soup.find_all('a', href=True)
# a = soup.find('a', href=True)

# %%
# patterns = [
#     'citycenter.jo/pc-and-laptops',
#     'citycenter.jo/computer-hardware-monitor-and-display',
#     'citycenter.jo/computer-hardware-peripherals',
#     'citycenter.jo/computer-hardware-audio',
#     'citycenter.jo/computer-hardware-storage',
#     'citycenter.jo/computer-hardware',
#     'citycenter.jo/gaming',
#     'citycenter.jo/peripherals-printer-and-scanner',
#     'citycenter.jo/electronics',
#     'citycenter.jo/Networking'
# ]

patterns = ['https://citycenter.jo/',
    'https://citycenter.jo/product/search?search']

# %%
# visited = set()
# queue = []
# visited.add(start)
# queue.append(start)
# max_depth = 20

# %%
visited = set()
# queue = deque()
visited.add(start)
# queue.append(start)
max_depth = 100
start_time = time.time()
num_links_found = 1

# current_depth = 0
page_iter = 1
print(f'[INFO] : start with link#{start}')

while page_iter <= max_pages:
    current_link = f'https://citycenter.jo/product/search?search=%20&page={page_iter}'
    # current_depth += 1
    response = requests.get(current_link)
    new_link_found = False
    print(f'[INFO] : Page = {page_iter} / {max_pages} : {current_link}')
    soup = BeautifulSoup(response.text, parser='lxml',features='lxml')

    all_links = soup.find_all('a', href=True)

    for link_text in all_links:
        link = link_text.get_attribute_list('href')[0]
        # print(link)
        valid_link = patterns[0] in link
        # search_link = patterns[1] in link
        
        if valid_link and link not in visited:
            num_links_found += 1
            visited.add(link)
            print(f'[INFO Page = {page_iter} / {max_pages}] : link #{num_links_found} : {link}')
            # new_link_found = True
            # if search_link:
            #     queue.append(link)
    page_iter += 1

    # if not new_link_found:
    #     current_depth -= 1
        
        # print(valid_link, link)
        # if valid_link and link not in visited:
        #     num_links_found += 1
        #     visited.add(link)
        #     queue.append(link)

finish_time = time.time() - start_time
print(f'[INFO] : finished in {finish_time:.2f}')
# Out:
# [INFO] : start with link#https://citycenter.jo/product/search?search=%20&page=1
# [INFO] : Page = 1 / 477 : https://citycenter.jo/product/search?search=%20&page=1
# [INFO Page = 1 / 477] : link #2 : https://citycenter.jo/account/account
# [INFO Page = 1 / 477] : link #3 : https://citycenter.jo/account/login
# [INFO Page = 1 / 477] : link #4 : https://citycenter.jo/account/register
# [INFO Page = 1 / 477] : link #5 : https://citycenter.jo/account/order
# [INFO Page = 1 / 477] : link #6 : https://citycenter.jo/account/wishlist
# [INFO Page = 1 / 477] : link #7 : https://citycenter.jo/account/address
# [INFO Page = 1 / 477] : link #8 : https://citycenter.jo/account/download
# [INFO Page = 1 / 477] : link #9 : https://citycenter.jo/account/transaction
# [INFO Page = 1 / 477] : link #10 : https://citycenter.jo/account/logout
# [INFO Page = 1 / 477] : link #11 : https://citycenter.jo/product/compare
# [INFO Page = 1 / 477] : link #12 : https://citycenter.jo/checkout/cart
# [INFO Page = 1 / 477] : link #13 : https://citycenter.jo/pc-and-laptops
# [INFO Page = 1 / 477] : link #14 : https://citycenter.jo/computer-hardware-monitor-and-display
# [INFO Page = 1 / 477] : link #15 : https://citycenter.jo//computer-hardware-peripherals
# [INFO Page = 1 / 477] : link #16 : https://citycenter.jo/computer-hardware-audio
# [INFO Page = 1 / 477] : link #17 : https://citycenter.jo/computer-hardware-storage
# [INFO Page = 1 / 477] : link #18 : https://citycenter.jo/computer-hardware
# [INFO Page = 1 / 477] : link #19 : https://citycenter.jo/gaming
# [INFO Page = 1 / 477] : link #20 : https://citycenter.jo/computer-hardware/computer-hardware-monitor-and-display
# [INFO Page = 1 / 477] : link #21 : https://citycenter.jo/peripherals-printer-and-scanner
# [INFO Page = 1 / 477] : link #22 : https://citycenter.jo/electronics
# [INFO Page = 1 / 477] : link #23 : https://citycenter.jo/Networking
# [INFO Page = 1 / 477] : link #24 : https://citycenter.jo/pc-and-laptops/computer-hardware-server-and-workstation
# [INFO Page = 1 / 477] : link #25 : https://citycenter.jo/pc-and-laptops/tablet-accessories
# [INFO Page = 1 / 477] : link #26 : https://citycenter.jo/pc-and-laptops/software
# [INFO Page = 1 / 477] : link #27 : https://citycenter.jo/computer-hardware/components-cpu-and-processor
# [INFO Page = 1 / 477] : link #28 : https://citycenter.jo/computer-hardware/components-fan-and-heatsink
# [INFO Page = 1 / 477] : link #29 : https://citycenter.jo/computer-hardware/components-motherboard
# [INFO Page = 1 / 477] : link #30 : https://citycenter.jo/computer-hardware/components-memory-ram
# [INFO Page = 1 / 477] : link #31 : https://citycenter.jo/computer-hardware/components-video-card
# [INFO Page = 1 / 477] : link #32 : https://citycenter.jo/computer-hardware/components-case-and-chassis
# [INFO Page = 1 / 477] : link #33 : https://citycenter.jo/computer-hardware/components-power-supply
# [INFO Page = 1 / 477] : link #34 : https://citycenter.jo/computer-hardware/components-hard-drive
# [INFO Page = 1 / 477] : link #35 : https://citycenter.jo/computer-hardware/components-blu-ray-dvd-drives
# [INFO Page = 1 / 477] : link #36 : https://citycenter.jo/computer-hardware/components-solid-state-drive-ssd
# [INFO Page = 1 / 477] : link #37 : https://citycenter.jo/computer-hardware/components-pcipci-e-add-card
# [INFO Page = 1 / 477] : link #38 : https://citycenter.jo/gaming/gaming-desk
# [INFO Page = 1 / 477] : link #39 : https://citycenter.jo/computer-hardware-monitor-and-display/ch-gaming-monitors
# [INFO Page = 1 / 477] : link #40 : https://citycenter.jo/computer-hardware-monitor-and-display/monitor-and-display-1415-lcdled-monitor
# [INFO Page = 1 / 477] : link #41 : https://citycenter.jo/computer-hardware-monitor-and-display/portable-monitors
# [INFO Page = 1 / 477] : link #42 : https://citycenter.jo/computer-hardware-monitor-and-display/lcd-led-monitors
# [INFO Page = 1 / 477] : link #43 : https://citycenter.jo/computer-hardware-peripherals/gaming-desks
# [INFO Page = 1 / 477] : link #44 : https://citycenter.jo/computer-hardware-peripherals/stream-equipment
# [INFO Page = 1 / 477] : link #45 : https://citycenter.jo/computer-hardware-peripherals/peripherals-cable
# [INFO Page = 1 / 477] : link #46 : https://citycenter.jo/computer-hardware-peripherals/peripherals-power-protection-and-ups
# [INFO Page = 1 / 477] : link #47 : https://citycenter.jo/computer-hardware-peripherals/peripherals-combo
# [INFO Page = 1 / 477] : link #48 : https://citycenter.jo/computer-hardware-peripherals/peripherals-keyboard
# [INFO Page = 1 / 477] : link #49 : https://citycenter.jo/computer-hardware-peripherals/peripherals-mouse
# [INFO Page = 1 / 477] : link #50 : https://citycenter.jo/computer-hardware-peripherals/peripherals-mouse-pad
# [INFO Page = 1 / 477] : link #51 : https://citycenter.jo/computer-hardware-peripherals/peripherals-gaming-accessories
# [INFO Page = 1 / 477] : link #52 : https://citycenter.jo/computer-hardware-peripherals/gaming-chairs
# [INFO Page = 1 / 477] : link #53 : https://citycenter.jo/computer-hardware-peripherals/peripherals-gaming-controller
# [INFO Page = 1 / 477] : link #54 : https://citycenter.jo/computer-hardware-peripherals/peripherals-graphics-tablet
# [INFO Page = 1 / 477] : link #55 : https://citycenter.jo/computer-hardware-peripherals/peripherals-wireless-pointer
# [INFO Page = 1 / 477] : link #56 : https://citycenter.jo/computer-hardware-peripherals/peripherals-webcam
# [INFO Page = 1 / 477] : link #57 : https://citycenter.jo/computer-hardware-audio/audio-mic
# [INFO Page = 1 / 477] : link #58 : https://citycenter.jo/computer-hardware-audio/audio-multimedia-player
# [INFO Page = 1 / 477] : link #59 : https://citycenter.jo/computer-hardware-audio/audio-sound-card
# [INFO Page = 1 / 477] : link #60 : https://citycenter.jo/computer-hardware-audio/audio-sound-pars
# [INFO Page = 1 / 477] : link #61 : https://citycenter.jo/computer-hardware-audio/audio-speaker-and-headset
# [INFO Page = 1 / 477] : link #62 : https://citycenter.jo/computer-hardware-storage/ssds-solid-state-drive
# [INFO Page = 1 / 477] : link #63 : https://citycenter.jo/computer-hardware-storage/internal-external-hdds
# [INFO Page = 1 / 477] : link #64 : https://citycenter.jo/computer-hardware-storage/blu-ray-dvd-drives
# [INFO Page = 1 / 477] : link #65 : https://citycenter.jo/computer-hardware-storage/storage-nas
# [INFO Page = 1 / 477] : link #66 : https://citycenter.jo/computer-hardware-storage/storage-external-enclosure
# [INFO Page = 1 / 477] : link #67 : https://citycenter.jo/computer-hardware-storage/storage-usb-pendrive
# [INFO Page = 1 / 477] : link #68 : https://citycenter.jo/computer-hardware-storage/storage-memory-card
# [INFO Page = 1 / 477] : link #69 : https://citycenter.jo/peripherals-printer-and-scanner/dot-matrix
# [INFO Page = 1 / 477] : link #70 : https://citycenter.jo/electronics/electronics-camera
# [INFO Page = 1 / 477] : link #71 : https://citycenter.jo/electronics/office-products
# [INFO Page = 1 / 477] : link #72 : https://citycenter.jo/electronics/electronics-point-sale
# [INFO Page = 1 / 477] : link #73 : https://citycenter.jo/electronics/computer-hardware-projector-and-screen
# [INFO Page = 1 / 477] : link #74 : https://citycenter.jo/electronics/electronics-security-and-surveillance
# [INFO Page = 12 / 477] : link #286 : https://citycenter.jo/pc-easy-ups-bv-1000va-600w-avr-universal-outlet?search=%20&page=12
# [INFO Page = 12 / 477] : link #287 : https://citycenter.jo/apc-easy-ups-bv-650va-375w-avr-automatic-voltage-regulation-universal-outlet?search=%20&page=12
# [INFO Page = 12 / 477] : link #288 : https://citycenter.jo/apc-easy-ups-bvx-700va-360w-avr-w-2x-universal-sockets-type-a-usb-port-for-smart-phone-tablet-charging?search=%20&page=12
# [INFO Page = 12 / 477] : link #289 : https://citycenter.jo/apc-easy-ups-on-line-srv-10000va-10000w-rm-with-extended-runtime-battery-pack?search=%20&page=12
# [INFO Page = 12 / 477] : link #290 : https://citycenter.jo/apc-easy-ups-on-line-srv-19-rail-kit-900mm-depth?search=%20&page=12
# [INFO Page = 12 / 477] : link #291 : https://citycenter.jo/apc-easy-ups-on-line-srv-2000va-1600w-double-conversion-online-sine-wave-rack?search=%20&page=12
# [INFO Page = 12 / 477] : link #292 : https://citycenter.jo/apc-easy-ups-on-line-srv-3000va-2400w-double-conversion-online-rack?search=%20&page=12
# [INFO Page = 12 / 477] : link #293 : https://citycenter.jo/apc-easy-ups-on-line-srv-6000va-6000w-rm-with-extended-runtime-battery-pack?search=%20&page=12
# [INFO Page = 12 / 477] : link #294 : https://citycenter.jo/apc-easy-ups-srv-240v-rackmount-lead-acid-battery-pack-for-6-10kva-rack-extended-runtime-model?search=%20&page=12
# [INFO Page = 12 / 477] : link #295 : https://citycenter.jo/apc-line-r-1000va-500w-automatic-voltage-regulator-3-universal-outlets-230v-black?search=%20&page=12
# [INFO Page = 12 / 477] : link #296 : https://citycenter.jo/apc-line-r-1500va-750w-automatic-voltage-regulator-3-universal-outlets-230v-black?search=%20&page=12
# [INFO Page = 12 / 477] : link #297 : https://citycenter.jo/apc-srv3ki-easy-ups-3kva-online-2400w-ups?search=%20&page=12
# [INFO Page = 12 / 477] : link #298 : https://citycenter.jo/apc-srv6ki-easy-ups-on-line-6kva-6000w-tower-230v-hard-wire-3-wire-1p-n-e-outlet-intelligent-card-slot-lcd?search=%20&page=12
# [INFO Page = 12 / 477] : link #299 : https://citycenter.jo/apc-surgearrest-essential-surge-protector-1x-universal-outlet-plug-uk-input?search=%20&page=12
# [INFO Page = 12 / 477] : link #300 : https://citycenter.jo/product/search?search=%20&page=16
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3413, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3409 exec_count = self.execution_count
#    3410 if result.error_in_exec:
#    3411     # Store formatted traceback and error details
#    3412     self.history_manager.exceptions[exec_count] = (
# -> 3413         self._format_exception_for_storage(result.error_in_exec)
#    3414     )
#    3416 # Each cell is a *single* input, regardless of how many lines it has
#    3417 self.execution_count += 1
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3467, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3464         stb = evalue._render_traceback_()
#    3465     else:
#    3466         # Otherwise, use InteractiveTB to format the traceback.
# -> 3467         stb = self.InteractiveTB.structured_traceback(
#    3468             etype, evalue, tb, tb_offset=1
#    3469         )
#    3470 except Exception:
#    3471     # In case formatting fails, fallback to Python's built-in formatting.
#    3472     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py:1185, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1183 else:
#    1184     self.tb = etb
# -> 1185 return FormattedTB.structured_traceback(
#    1186     self, etype, evalue, etb, tb_offset, context
#    1187 )
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py:1056, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1053 mode = self.mode
#    1054 if mode in self.verbose_modes:
#    1055     # Verbose modes need a full traceback
# -> 1056     return VerboseTB.structured_traceback(
#    1057         self, etype, evalue, etb, tb_offset, context
#    1058     )
#    1059 elif mode == "Docs":
#    1060     # return DocTB
#    1061     return DocTB(
#    1062         theme_name=self._theme_name,
#    1063         call_pdb=self.call_pdb,
#    (...)   1071         etype, evalue, etb, tb_offset, 1
#    1072     )  # type: ignore[arg-type]
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py:864, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     855 def structured_traceback(
#     856     self,
#     857     etype: type,
#    (...)    861     context: int = 5,
#     862 ) -> list[str]:
#     863     """Return a nice text document describing the traceback."""
# --> 864     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     865         etype, evalue, etb, context, tb_offset
#     866     )
#     868     termsize = min(75, get_terminal_size()[0])
#     869     theme = theme_table[self._theme_name]
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py:776, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     766         frames.append(
#     767             theme_table[self._theme_name].format(
#     768                 [
#    (...)    773             )
#     774         )
#     775         skipped = 0
# --> 776     frames.append(self.format_record(record))
#     777 if skipped:
#     778     frames.append(
#     779         theme_table[self._theme_name].format(
#     780             [
#    (...)    785         )
#     786     )
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py:651, in VerboseTB.format_record(self, frame_info)
#     648 result += ", " if call else ""
#     649 result += f"{call}\n"
#     650 result += theme_table[self._theme_name].format(
# --> 651     _format_traceback_lines(
#     652         frame_info.lines,
#     653         theme_table[self._theme_name],
#     654         self.has_colors,
#     655         lvals_toks,
#     656     )
#     657 )
#     658 return result
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/IPython/core/tbtools.py:99, in _format_traceback_lines(lines, theme, has_colors, lvals_toks)
#      96     continue
#      98 lineno = stack_line.lineno
# ---> 99 line = stack_line.render(pygmented=has_colors).rstrip("\n") + "\n"
#     100 if stack_line.is_current:
#     101     # This is the line with the error
#     102     pad = numbers_width - len(str(lineno))
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/stack_data/core.py:391, in Line.render(self, markers, strip_leading_indent, pygmented, escape_html)
#     389 if pygmented and self.frame_info.scope:
#     390     assert_(not markers, ValueError("Cannot use pygmented with markers"))
# --> 391     start_line, lines = self.frame_info._pygmented_scope_lines
#     392     result = lines[self.lineno - start_line]
#     393     if strip_leading_indent:
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/stack_data/utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/stack_data/core.py:824, in FrameInfo._pygmented_scope_lines(self)
#     821     ranges = []
#     823 code = atext.get_text(scope)
# --> 824 lines = _pygmented_with_ranges(formatter, code, ranges)
#     826 start_line = self.source.line_range(scope)[0]
#     828 return start_line, lines
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/stack_data/utils.py:166, in _pygmented_with_ranges(formatter, code, ranges)
#     164 lexer = MyLexer(stripnl=False)
#     165 try:
# --> 166     highlighted = pygments.highlight(code, lexer, formatter)
#     167 except Exception:
#     168     # When pygments fails, prefer code without highlighting over crashing
#     169     highlighted = code
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/pygments/__init__.py:82, in highlight(code, lexer, formatter, outfile)
#      77 def highlight(code, lexer, formatter, outfile=None):
#      78     """
#      79     This is the most high-level highlighting function. It combines `lex` and
#      80     `format` in one function.
#      81     """
# ---> 82     return format(lex(code, lexer), formatter, outfile)
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/pygments/__init__.py:64, in format(tokens, formatter, outfile)
#      62 if not outfile:
#      63     realoutfile = getattr(formatter, 'encoding', None) and BytesIO() or StringIO()
# ---> 64     formatter.format(tokens, realoutfile)
#      65     return realoutfile.getvalue()
#      66 else:
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/pygments/formatters/terminal256.py:250, in Terminal256Formatter.format(self, tokensource, outfile)
#     249 def format(self, tokensource, outfile):
# --> 250     return Formatter.format(self, tokensource, outfile)
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/pygments/formatter.py:124, in Formatter.format(self, tokensource, outfile)
#     121 if self.encoding:
#     122     # wrap the outfile in a StreamWriter
#     123     outfile = codecs.lookup(self.encoding)[3](outfile)
# --> 124 return self.format_unencoded(tokensource, outfile)
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/pygments/formatters/terminal256.py:256, in Terminal256Formatter.format_unencoded(self, tokensource, outfile)
#     253 if self.linenos:
#     254     self._write_lineno(outfile)
# --> 256 for ttype, value in tokensource:
#     257     not_found = True
#     258     while ttype and not_found:
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/stack_data/utils.py:159, in _pygmented_with_ranges.<locals>.MyLexer.get_tokens(self, text)
#     157 length = 0
#     158 for ttype, value in super().get_tokens(text):
# --> 159     if any(start <= length < end for start, end in ranges):
#     160         ttype = ttype.ExecutingNode
#     161     length += len(value)
#
# File ~/PycharmProjects/One_Place/.venv/lib/python3.12/site-packages/stack_data/utils.py:159, in <genexpr>(.0)
#     157 length = 0
#     158 for ttype, value in super().get_tokens(text):
# --> 159     if any(start <= length < end for start, end in ranges):
#     160         ttype = ttype.ExecutingNode
#     161     length += len(value)
#
# KeyboardInterrupt:

# %%
def pattern_exists(link,pattern):
    return pattern in link

# %%
# for a in all_as:
#     link = a.get_attribute_list('href')[0]

#     valid_link = 'citycenter.jo' in link
#     valid_sub = any([pattern_exists(link,pattern) for pattern in patterns])
#     if valid_link:
#         if valid_sub and link not in visited:
#             visited.add(link)
#             queue.append(link)

# %%
len(visited)
# Out:
# 117

# %%
all_found_links = list(visited)

# %%
df_dict = {
    'Links' : all_found_links
}

# %%
df = pd.DataFrame(df_dict)

# %%
df.head()
# Out:
#                                                Links
# 0  https://citycenter.jo/computer-hardware-periph...
# 1  https://citycenter.jo/acefast-c3-03-usb-c-to-u...
# 2  https://citycenter.jo/computer-hardware/compon...
# 3  https://citycenter.jo/computer-hardware-storag...
# 4  https://citycenter.jo/electronics/office-products

# %%
df.to_csv('all_found_links.csv')
